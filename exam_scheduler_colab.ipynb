# %% [markdown]
# # Exam Scheduler trên Google Colab
#
# Hướng dẫn: tải repo lên Colab hoặc mount Google Drive, cài đặt dependencies và chạy `main.py`.

# %% [markdown]
# ## 1) Cài đặt dependencies
#
# Chạy cell này trước khi chạy mô hình.

# %%
# !pip install -q pandas>=1.5.0 openpyxl>=3.1.0 pulp>=2.7.0 numpy>=1.24.0

# %% [markdown]
# ## 2) Chuẩn bị mã nguồn
#
# Nếu bạn đã upload repository zip vào Colab, giải nén nó. Nếu dùng Google Drive, mount drive và duyệt đến thư mục.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Nếu repo đã được upload dưới dạng exam_scheduler.zip
# !unzip -q /content/exam_scheduler.zip -d /content/exam_scheduler

# Kiểm tra nội dung thư mục
# !find /content -maxdepth 2 -type f | sed -n '1,50p'

# %% [markdown]
# ## 3) Chạy mô hình
#
# Thay `PATH_TO_REPO` bằng thư mục chứa repo của bạn trên Colab.

# %%
# %cd /content/exam_scheduler
# !python main.py
